# %%
import itertools

import rmgpy

from rmgpy.data.rmg import RMGDatabase
from rmgpy.rmg.react import *
from rmgpy.reaction import Reaction
from rmgpy.molecule.molecule import Molecule
from rmgpy.molecule.resonance import *
from rmgpy.species import Species
from rmgpy.data.kinetics.common import filter_reactions

from rmgpy.data.rmg import getDB
from rmgpy.scoop_framework.util import map_
from copy import deepcopy
from IPython.display import display

# %%
import numpy as np

# %%
import afm.utils_1_sided
import odesimulator_2mo

# %%
		conc1 = [(('LY', 'XR'), 1),
			   	 (('XR', 'LWL', 'XR'), 2),
			   	 (('LY', 'TR'), 3)]
		conc2 = [(('LWL', 'RUR'), 3),
				 ('LQR', 3)]

# %%
matches = afm.utils_1_sided.match_concentrations_with_different_sums(conc1, conc2)
# Out:
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(135)match_concentrations_with_different_sums()
# -> while True:
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(136)match_concentrations_with_different_sums()
# -> if val1 > val2:
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(144)match_concentrations_with_different_sums()
# -> elif val1 < val2:
# (Pdb) val1
# 1
# (Pdb) val2
# 3
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(145)match_concentrations_with_different_sums()
# -> match = ((labels1[pin1], labels2[pin2]), val1)
# (Pdb)
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(146)match_concentrations_with_different_sums()
# -> matches_conc.append(match)
# (Pdb) match
# ((('LY', 'XR'), ('LWL', 'RUR')), 1)
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(147)match_concentrations_with_different_sums()
# -> val2 = val2 - val1
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(148)match_concentrations_with_different_sums()
# -> pin1 += 1
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(149)match_concentrations_with_different_sums()
# -> if pin1 == len(seq1):
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(151)match_concentrations_with_different_sums()
# -> val1 = seq1[pin1]
# (Pdb) val1
# 1
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(135)match_concentrations_with_different_sums()
# -> while True:
# (Pdb) val1
# 2
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(136)match_concentrations_with_different_sums()
# -> if val1 > val2:
# (Pdb) val2
# 2
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(144)match_concentrations_with_different_sums()
# -> elif val1 < val2:
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(153)match_concentrations_with_different_sums()
# -> match = ((labels1[pin1], labels2[pin2]), val1)
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(154)match_concentrations_with_different_sums()
# -> matches_conc.append(match)
# (Pdb) match
# ((('XR', 'LWL', 'XR'), ('LWL', 'RUR')), 2)
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(155)match_concentrations_with_different_sums()
# -> pin1 += 1
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(156)match_concentrations_with_different_sums()
# -> pin2 += 1
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(157)match_concentrations_with_different_sums()
# -> if pin1 == len(seq1):
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(159)match_concentrations_with_different_sums()
# -> val1 = seq1[pin1]
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(160)match_concentrations_with_different_sums()
# -> if pin2 == len(seq2):
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(162)match_concentrations_with_different_sums()
# -> val2 = seq2[pin2]
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(135)match_concentrations_with_different_sums()
# -> while True:
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(136)match_concentrations_with_different_sums()
# -> if val1 > val2:
# (Pdb) val1
# 3
# (Pdb) val2
# 3
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(144)match_concentrations_with_different_sums()
# -> elif val1 < val2:
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(153)match_concentrations_with_different_sums()
# -> match = ((labels1[pin1], labels2[pin2]), val1)
# (Pdb) val1
# 3
# (Pdb) val2
# 3
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(154)match_concentrations_with_different_sums()
# -> matches_conc.append(match)
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(155)match_concentrations_with_different_sums()
# -> pin1 += 1
# (Pdb) match
# ((('LY', 'TR'), 'LQR'), 3)
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(156)match_concentrations_with_different_sums()
# -> pin2 += 1
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(157)match_concentrations_with_different_sums()
# -> if pin1 == len(seq1):
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(158)match_concentrations_with_different_sums()
# -> break
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(166)match_concentrations_with_different_sums()
# -> if pin2 == len(seq2) and pin1 < len(seq1):
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(172)match_concentrations_with_different_sums()
# -> elif pin1 == len(seq1) and pin2 < len(seq2):
# (Pdb) n
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(178)match_concentrations_with_different_sums()
# -> return matches_conc
# (Pdb) n
# --Return--
# > /home/yentingw/AutoFragmentModeling/afm/utils_1_sided.py(178)match_concentrations_with_different_sums()->[((('LY', 'XR'), ('LWL', 'RUR')), 1), ((('XR', 'LWL', 'XR'), ('LWL', 'RUR')), 2), ((('LY', 'TR'), 'LQR'), 3)]
# -> return matches_conc
# (Pdb) n
# --Return--
# > <ipython-input-5-f58580ee9b10>(1)<module>()->None
# -> matches = afm.utils_1_sided.match_concentrations_with_different_sums(conc1, conc2)
# (Pdb) matches_conc
# *** NameError: name 'matches_conc' is not defined
# (Pdb) n
# > /home/yentingw/anaconda2/envs/rmg_env/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2885)run_code()
# -> sys.excepthook = old_excepthook
# (Pdb) n
# > /home/yentingw/anaconda2/envs/rmg_env/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2901)run_code()
# -> outflag = 0
# (Pdb) n
# > /home/yentingw/anaconda2/envs/rmg_env/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2902)run_code()
# -> return outflag
# (Pdb) n
# --Return--
# > /home/yentingw/anaconda2/envs/rmg_env/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2902)run_code()->0
# -> return outflag
# (Pdb) n
# > /home/yentingw/anaconda2/envs/rmg_env/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2819)run_ast_nodes()
# -> for i, node in enumerate(to_run_exec):
# (Pdb) n
# > /home/yentingw/anaconda2/envs/rmg_env/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2825)run_ast_nodes()
# -> for i, node in enumerate(to_run_interactive):

# %%
from afm.utils import categorize_fragments
