# %%
SMILES_files = []
for root, dirs, files in os.walk("../RMG-models", topdown=False):
	for name in files:
		if str(os.path.join(root,name)).endswith('SMILES.txt'):
			SMILES_files.append(os.path.join(root,name))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4b39208a8757> in <module>()
#       1 SMILES_files = []
# ----> 2 for root, dirs, files in os.walk("../RMG-models", topdown=False):
#       3         for name in files:
#       4                 if str(os.path.join(root,name)).endswith('SMILES.txt'):
#       5                         SMILES_files.append(os.path.join(root,name))
#
# NameError: name 'os' is not defined

# %%
import os

# %%
SMILES_files = []
for root, dirs, files in os.walk("../RMG-models", topdown=False):
	for name in files:
		if str(os.path.join(root,name)).endswith('SMILES.txt'):
			SMILES_files.append(os.path.join(root,name))

# %%
kinetics_files = []
for root, dirs, files in os.walk("../RMG-models", topdown=False):
	for name in files:
		if str(os.path.join(root,name)).endswith('kinetics.py'):
			kinetics_files.append(os.path.join(root,name))

# %%
SMILES_files
# Out:
# ['../RMG-models/AramcoMech_1.3/SMILES.txt',
#  '../RMG-models/AramcoMech_2.0/SMILES.txt',
#  '../RMG-models/Biomass/SMILES.txt',
#  '../RMG-models/Chernov/SMILES.txt',
#  '../RMG-models/CombFlame2013/1315-Chang/SMILES.txt',
#  '../RMG-models/CombFlame2013/1541-Zhang/SMILES.txt',
#  '../RMG-models/CombFlame2013/1609-Veloo/SMILES.txt',
#  '../RMG-models/CombFlame2013/17-Malewicki/SMILES.txt',
#  '../RMG-models/CombFlame2013/1907-Merchant/SMILES.txt',
#  '../RMG-models/CombFlame2013/1939-Cai/SMILES.txt',
#  '../RMG-models/CombFlame2013/1958-Zhao/SMILES.txt',
#  '../RMG-models/CombFlame2013/2291-Somers/SMILES.txt',
#  '../RMG-models/CombFlame2013/2319-Serinyel/SMILES.txt',
#  '../RMG-models/CombFlame2013/2343-Hansen/SMILES.txt',
#  '../RMG-models/CombFlame2013/2680-Vranckx/SMILES.txt',
#  '../RMG-models/CombFlame2013/2693-Karwat/SMILES.txt',
#  '../RMG-models/CombFlame2013/2712-Sarathy/SMILES.txt',
#  '../RMG-models/CombFlame2013/487-Schenk/SMILES.txt',
#  '../RMG-models/CombFlame2013/853-Alzueta/SMILES.txt',
#  '../RMG-models/CombFlame2014/1135-Dames/SMILES.txt',
#  '../RMG-models/CombFlame2014/1146-Rotavera/SMILES.txt',
#  '../RMG-models/CombFlame2014/1516-Xuan/SMILES.txt',
#  '../RMG-models/CombFlame2014/405-Cai/SMILES.txt',
#  '../RMG-models/CombFlame2014/644-Man/SMILES.txt',
#  '../RMG-models/CombFlame2014/65-Darcy/SMILES.txt',
#  '../RMG-models/CombFlame2014/657-Jin/SMILES.txt',
#  '../RMG-models/CombFlame2014/711-Allen/SMILES.txt',
#  '../RMG-models/CombFlame2014/748-Liu/SMILES.txt',
#  '../RMG-models/CombFlame2014/798-Cai/SMILES.txt',
#  '../RMG-models/CombFlame2014/818-Zhang/SMILES.txt',
#  '../RMG-models/CombFlame2014/84-Wang/SMILES.txt',
#  '../RMG-models/CombFlame2014/885-Xiong/SMILES.txt',
#  '../RMG-models/CombFlame2014/898-Wagnon/SMILES.txt',
#  '../RMG-models/CombFlame2015/3755-Konnov/SMILES.txt',
#  '../RMG-models/Gasoline_2/SMILES.txt',
#  '../RMG-models/Gasoline_Surrogate/SMILES.txt',
#  '../RMG-models/GoldsboroughNOx/SMILES.txt',
#  '../RMG-models/GRI-17-species-mech/SMILES.txt',
#  '../RMG-models/GRI-mech-3.0/SMILES.txt',
#  '../RMG-models/H2/SMILES.txt',
#  '../RMG-models/H2-3/SMILES.txt',
#  '../RMG-models/IJCK2013/638-Metcalfe/SMILES.txt',
#  '../RMG-models/JPCA2013/1371-Sirjean/SMILES.txt',
#  '../RMG-models/MatheuCH4/SMILES.txt',
#  '../RMG-models/MB-Dooley/SMILES.txt',
#  '../RMG-models/MB-Farooq/SMILES.txt',
#  '../RMG-models/MB-Fisher/SMILES.txt',
#  '../RMG-models/n-Heptane/SMILES.txt',
#  '../RMG-models/Narayanaswamy/SMILES.txt',
#  '../RMG-models/PCI2013/187-Wang/SMILES.txt',
#  '../RMG-models/PCI2013/225-Somers/SMILES.txt',
#  '../RMG-models/PCI2013/259-Labbe/SMILES.txt',
#  '../RMG-models/PCI2013/269-Matsugi/SMILES.txt',
#  '../RMG-models/PCI2013/289-Dagaut/SMILES.txt',
#  '../RMG-models/PCI2013/297-Herbinet/SMILES.txt',
#  '../RMG-models/PCI2013/325-Husson/SMILES.txt',
#  '../RMG-models/PCI2013/335-Wang/SMILES.txt',
#  '../RMG-models/PCI2013/353-Malewicki/SMILES.txt',
#  '../RMG-models/PCI2013/361-Malewicki/SMILES.txt',
#  '../RMG-models/PCI2013/401-Liu/SMILES.txt',
#  '../RMG-models/PCI2013/411-Darcy/SMILES.txt',
#  '../RMG-models/PCI2013/519-Zador/SMILES.txt',
#  '../RMG-models/PCI2013/527-Sheen/SMILES.txt',
#  '../RMG-models/PCI2013/599-Veloo/SMILES.txt',
#  '../RMG-models/PCI2013/617-Zhang/SMILES.txt',
#  '../RMG-models/PCI2015/0153-Marshall/SMILES.txt',
#  '../RMG-models/PCI2015/0325-Nawdiyal/SMILES.txt',
#  '../RMG-models/PCI2015/0409-Zhang/SMILES.txt',
#  '../RMG-models/PCI2017/005-Kraus/SMILES.txt',
#  '../RMG-models/PCI2017/012-Felsmann/SMILES.txt',
#  '../RMG-models/PCI2017/022-Thion/SMILES.txt',
#  '../RMG-models/PCI2017/024-Bohon/SMILES.txt',
#  '../RMG-models/PCI2017/025-Sudholt/SMILES.txt',
#  '../RMG-models/PCI2017/032-Cheng/SMILES.txt',
#  '../RMG-models/PCI2017/036-Rashidi/SMILES.txt',
#  '../RMG-models/PCI2017/037-Sakai/SMILES.txt',
#  '../RMG-models/PCI2017/038-Labbe-Zhao(30Torr-10Atm)/SMILES.txt',
#  '../RMG-models/PCI2017/047-Rodriguez/SMILES.txt',
#  '../RMG-models/PCI2017/051-Pelucchi/SMILES.txt',
#  '../RMG-models/PCI2017/052-Li/SMILES.txt',
#  '../RMG-models/PCI2017/052-Stagni/SMILES.txt',
#  '../RMG-models/PCI2017/058-Sun/SMILES.txt',
#  '../RMG-models/PCI2017/082-Hemken/SMILES.txt',
#  '../RMG-models/PCI2017/087-Tran/SMILES.txt',
#  '../RMG-models/PCI2017/111-Jin/SMILES.txt',
#  '../RMG-models/PCI2017/145-Sun/SMILES.txt',
#  '../RMG-models/Reduced-DRG-GRI-mech/SMILES.txt',
#  '../RMG-models/Shamel-Propane/SMILES.txt',
#  '../RMG-models/USC_Mech_ii/SMILES.txt']

# %%
kinetics_files
# Out:
# ['../RMG-models/AramcoMech_1.3/AramcoMech_1.3_C4_chem.kinetics.py',
#  '../RMG-models/AramcoMech_2.0/Aramco2.0.kinetics.py',
#  '../RMG-models/Biomass/SpRxn.kinetics.py',
#  '../RMG-models/Chernov/Chernov_2014_chemkin.kinetics.py',
#  '../RMG-models/CombFlame2013/1315-Chang/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2013/1541-Zhang/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2013/1609-Veloo/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2013/17-Malewicki/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2013/1907-Merchant/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2013/1939-Cai/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2013/1958-Zhao/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2013/2291-Somers/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2013/2319-Serinyel/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2013/2343-Hansen/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2013/2680-Vranckx/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2013/2693-Karwat/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2013/2712-Sarathy/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2013/487-Schenk/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2013/853-Alzueta/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2014/1135-Dames/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2014/405-Cai/optimizedmechanism.kinetics.py',
#  '../RMG-models/CombFlame2014/405-Cai/unoptimizedmechanism.kinetics.py',
#  '../RMG-models/CombFlame2014/65-Darcy/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2014/657-Jin/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2014/711-Allen/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2014/748-Liu/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2014/798-Cai/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2014/818-Zhang/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2014/84-Wang/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2014/885-Xiong/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2014/898-Wagnon/mechanism.kinetics.py',
#  '../RMG-models/CombFlame2015/3755-Konnov/mechanism.kinetics.py',
#  '../RMG-models/Gasoline_2/llnl.gasoline.mar2014.chem.kinetics.py',
#  '../RMG-models/Gasoline_Surrogate/Gasolinemechanism.kinetics.py',
#  '../RMG-models/GRI-17-species-mech/mechanism.kinetics.py',
#  '../RMG-models/GRI-mech-3.0/mechanism.kinetics.py',
#  '../RMG-models/H2/chem.kinetics.py',
#  '../RMG-models/H2-3/Burke_Konnov_Mech3.kinetics.py',
#  '../RMG-models/IJCK2013/638-Metcalfe/mechanism.kinetics.py',
#  '../RMG-models/JPCA2013/1371-Sirjean/mechanism.kinetics.py',
#  '../RMG-models/MatheuCH4/Matheu_CH4_pyrolysis_gas_kinetics.kinetics.py',
#  '../RMG-models/MB-Dooley/mb_cnf_08.kinetics.py',
#  '../RMG-models/MB-Farooq/mmc1.kinetics.py',
#  '../RMG-models/MB-Fisher/mbmechrev.kinetics.py',
#  '../RMG-models/n-Heptane/nc7_ver3.1_mech.kinetics.py',
#  '../RMG-models/Narayanaswamy/Narayanaswamy_2010_chemkin.kinetics.py',
#  '../RMG-models/PCI2013/225-Somers/mechanism.kinetics.py',
#  '../RMG-models/PCI2013/259-Labbe/mechanism.kinetics.py',
#  '../RMG-models/PCI2013/269-Matsugi/mechanism.kinetics.py',
#  '../RMG-models/PCI2013/289-Dagaut/mechanism.kinetics.py',
#  '../RMG-models/PCI2013/297-Herbinet/mechanism.kinetics.py',
#  '../RMG-models/PCI2013/325-Husson/mechanism.kinetics.py',
#  '../RMG-models/PCI2013/335-Wang/mechanism.kinetics.py',
#  '../RMG-models/PCI2013/353-Malewicki/mechanism.kinetics.py',
#  '../RMG-models/PCI2013/361-Malewicki/mechanism.kinetics.py',
#  '../RMG-models/PCI2013/401-Liu/mechanism.kinetics.py',
#  '../RMG-models/PCI2013/411-Darcy/mechanism.kinetics.py',
#  '../RMG-models/PCI2013/527-Sheen/mechanism.kinetics.py',
#  '../RMG-models/PCI2013/599-Veloo/mechanism.kinetics.py',
#  '../RMG-models/PCI2013/617-Zhang/mechanism.kinetics.py',
#  '../RMG-models/PCI2015/0153-Marshall/mechanism.kinetics.py',
#  '../RMG-models/PCI2015/0325-Nawdiyal/mechanism.kinetics.py',
#  '../RMG-models/PCI2015/0409-Zhang/mechanism.kinetics.py',
#  '../RMG-models/Reduced-DRG-GRI-mech/mechanism.kinetics.py',
#  '../RMG-models/Shamel-Propane/propane_full_mechanism.kinetics.py',
#  '../RMG-models/USC_Mech_ii/USC_Mech_ver_II.kinetics.py']

# %%
len(SMILES_files) == len(kinetics_files)
# Out:
# False

# %%
smiles_dict = {}
for name in SMILES_files:
	try:
		e,d,c,b,a = name.split('/')
		smiles_entry = c + "_" + b
		test = str(e + '/' + d + '/' + c)
# Out:
#   File "<ipython-input-9-37c8237e5ea3>", line 6
#     test = str(e + '/' + d + '/' + c)
#                                      ^
# IndentationError: unexpected unindent

# %%
smiles_dict = {}

# %%
for name in SMILES_files:
    try:
        e,d,c,b,a = name.split('/')
        smiles_entry = c+ '_' +b
        test = e+'/'+d+'/'+c
    except:
        pass

# %%
test
# Out:
# '../RMG-models/PCI2017'

# %%
if test in kinetics_files:
    kinetics_entry = (s for s in list if sub in s)
    smiles_dict[smiles_entry] = [name, kinetics_entry]

# %%
smiles_dict
# Out:
# {}

# %%
kinetics_entry
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-7e7e4a5c0328> in <module>()
# ----> 1 kinetics_entry
#
# NameError: name 'kinetics_entry' is not defined

# %%
importer_files = []
for root, dirs, files in os.walk("../RMG-models", topdown=False):
	smiles_file = None
	kinetics_file = None
	for name in files:
		if str(os.path.join(root,name)).endswith('SMILES.txt'):
			smiles_file = os.path.join(root,name)
		if str(os.path.join(root,name)).endswith('kinetics.py'):
			kinetics_file = os.path.join(root,name)
	if kinetics_file and smiles_file:
		importer_files.append((smiles_file, kinetics_file))
	else:
		print root
		if smiles_file is None:
			print "Missing SMILES file"
		if kinetics_file is None:
			print "Missing kinetics file"
# Out:
# ../RMG-models/.git/branches
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/.git/hooks
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/.git/info
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/.git/logs/refs/heads
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/.git/logs/refs/remotes/origin
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/.git/logs/refs/remotes
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/.git/logs/refs
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/.git/logs
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/.git/objects/info
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/.git/objects/pack
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/.git/objects
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/.git/refs/heads
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/.git/refs/remotes/origin
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/.git/refs/remotes
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/.git/refs/tags
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/.git/refs
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/.git
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/AramcoMech_1.3/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/AramcoMech_1.3/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/AramcoMech_2.0/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/AramcoMech_2.0/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/Biomass/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/Biomass/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/Chernov/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/Chernov/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2013/1153-Aul
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2013/1315-Chang/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2013/1315-Chang/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2013/1541-Zhang/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2013/1541-Zhang/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2013/1609-Veloo/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2013/1609-Veloo/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2013/17-Malewicki/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2013/17-Malewicki/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2013/1939-Cai/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2013/1939-Cai/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2013/1958-Zhao/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2013/1958-Zhao/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2013/2291-Somers/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2013/2291-Somers/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2013/2680-Vranckx/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2013/2680-Vranckx/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2013/2712-Sarathy/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2013/2712-Sarathy/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2013/487-Schenk/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2013/487-Schenk/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2013
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2014/1135-Dames/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2014/1135-Dames/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2014/1146-Rotavera
# Missing kinetics file
# ../RMG-models/CombFlame2014/1460-Darcy
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2014/1516-Xuan
# Missing kinetics file
# ../RMG-models/CombFlame2014/405-Cai/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2014/405-Cai/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2014/644-Man
# Missing kinetics file
# ../RMG-models/CombFlame2014/65-Darcy/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2014/65-Darcy/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2014/657-Jin/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2014/657-Jin/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2014/798-Cai/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2014/798-Cai/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2014/818-Zhang/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2014/818-Zhang/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2014/84-Wang/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2014/84-Wang/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2014/885-Xiong/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2014/885-Xiong/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2014
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2015/3755-Konnov/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2015/3755-Konnov/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/CombFlame2015
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/Gasoline_2/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/Gasoline_2/RMG-Py-output/pdep
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/Gasoline_2/RMG-Py-output/species
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/Gasoline_2/RMG-Py-output
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/Gasoline_2/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/Gasoline_Surrogate/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/Gasoline_Surrogate/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/GoldsboroughNOx
# Missing kinetics file
# ../RMG-models/GRI-17-species-mech/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/GRI-17-species-mech/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/GRI-mech-3.0/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/GRI-mech-3.0/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/H2/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/H2/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/H2-3/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/H2-3/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/IJCK2013/638-Metcalfe/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/IJCK2013/638-Metcalfe/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/IJCK2013
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/JPCA2013
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/MatheuCH4/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/MatheuCH4/RMG-Py-output
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/MatheuCH4/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/MB-Dooley/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/MB-Dooley/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/MB-Farooq/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/MB-Farooq/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/MB-Fisher/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/MB-Fisher/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/modelComparer
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/n-Heptane/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/n-Heptane/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/Narayanaswamy/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/Narayanaswamy/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2009/367-Lopez
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2009/403-You
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2009/437-Naik
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2009
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2011/209-Dievart
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2011/367-Togbe
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2011/399-Sarathy
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2011
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/187-Wang
# Missing kinetics file
# ../RMG-models/PCI2013/225-Somers/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/225-Somers/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/259-Labbe/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/259-Labbe/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/269-Matsugi/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/269-Matsugi/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/289-Dagaut/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/289-Dagaut/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/297-Herbinet/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/297-Herbinet/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/325-Husson/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/325-Husson/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/335-Wang/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/335-Wang/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/353-Malewicki/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/353-Malewicki/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/361-Malewicki/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/361-Malewicki/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/401-Liu/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/401-Liu/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/411-Darcy/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/411-Darcy/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/519-Zador
# Missing kinetics file
# ../RMG-models/PCI2013/527-Sheen/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/527-Sheen/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/537-Manion
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/599-Veloo/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013/599-Veloo/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2013
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2015/0153-Marshall/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2015/0153-Marshall/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2015/0325-Nawdiyal/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2015/0325-Nawdiyal/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2015/0409-Zhang/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2015/0409-Zhang/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2015
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/005-Kraus
# Missing kinetics file
# ../RMG-models/PCI2017/012-Felsmann/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/012-Felsmann/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/012-Felsmann
# Missing kinetics file
# ../RMG-models/PCI2017/022-Thion/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/022-Thion/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/022-Thion
# Missing kinetics file
# ../RMG-models/PCI2017/024-Bohon/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/024-Bohon/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/024-Bohon
# Missing kinetics file
# ../RMG-models/PCI2017/025-Sudholt/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/025-Sudholt/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/025-Sudholt
# Missing kinetics file
# ../RMG-models/PCI2017/032-Cheng/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/032-Cheng/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/032-Cheng
# Missing kinetics file
# ../RMG-models/PCI2017/036-Rashidi/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/036-Rashidi/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/036-Rashidi
# Missing kinetics file
# ../RMG-models/PCI2017/037-Sakai/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/037-Sakai/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/037-Sakai
# Missing kinetics file
# ../RMG-models/PCI2017/038-Labbe-Zhao(30Torr-10Atm)/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/038-Labbe-Zhao(30Torr-10Atm)/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/038-Labbe-Zhao(30Torr-10Atm)
# Missing kinetics file
# ../RMG-models/PCI2017/047-Rodriguez/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/047-Rodriguez/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/047-Rodriguez
# Missing kinetics file
# ../RMG-models/PCI2017/051-Pelucchi/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/051-Pelucchi/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/051-Pelucchi
# Missing kinetics file
# ../RMG-models/PCI2017/052-Li/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/052-Li/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/052-Li
# Missing kinetics file
# ../RMG-models/PCI2017/052-Stagni/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/052-Stagni/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/052-Stagni
# Missing kinetics file
# ../RMG-models/PCI2017/058-Sun/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/058-Sun/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/058-Sun
# Missing kinetics file
# ../RMG-models/PCI2017/082-Hemken/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/082-Hemken/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/082-Hemken
# Missing kinetics file
# ../RMG-models/PCI2017/087-Tran/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/087-Tran/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/087-Tran
# Missing kinetics file
# ../RMG-models/PCI2017/111-Jin/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/111-Jin/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/111-Jin
# Missing kinetics file
# ../RMG-models/PCI2017/145-Sun/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/145-Sun/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/PCI2017/145-Sun
# Missing kinetics file
# ../RMG-models/PCI2017
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/Reduced-DRG-GRI-mech/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/Reduced-DRG-GRI-mech/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/Shamel-Propane/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/Shamel-Propane/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/translations
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/USC_Mech_ii/RMG-Py-kinetics-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models/USC_Mech_ii/RMG-Py-thermo-library
# Missing SMILES file
# Missing kinetics file
# ../RMG-models
# Missing SMILES file
# Missing kinetics file

# %%
importer_files[13][1]
# Out:
# '../RMG-models/CombFlame2013/2343-Hansen/mechanism.kinetics.py'

# %%
len(importer_files)
# Out:
# 65

# %%
for entry in importer_files:
	smiles_file = entry[0]
	kinetics_file = entry[1]
    print smiles_file, kinetics_file
# Out:
#   File "<ipython-input-22-441af7080999>", line 4
#     print smiles_file, kinetics_file
#                                     ^
# IndentationError: unindent does not match any outer indentation level

# %%
for entry in importer_files:
    print entry[0]
    print entry[1]
# Out:
# ../RMG-models/AramcoMech_1.3/SMILES.txt
# ../RMG-models/AramcoMech_1.3/AramcoMech_1.3_C4_chem.kinetics.py
# ../RMG-models/AramcoMech_2.0/SMILES.txt
# ../RMG-models/AramcoMech_2.0/Aramco2.0.kinetics.py
# ../RMG-models/Biomass/SMILES.txt
# ../RMG-models/Biomass/SpRxn.kinetics.py
# ../RMG-models/Chernov/SMILES.txt
# ../RMG-models/Chernov/Chernov_2014_chemkin.kinetics.py
# ../RMG-models/CombFlame2013/1315-Chang/SMILES.txt
# ../RMG-models/CombFlame2013/1315-Chang/mechanism.kinetics.py
# ../RMG-models/CombFlame2013/1541-Zhang/SMILES.txt
# ../RMG-models/CombFlame2013/1541-Zhang/mechanism.kinetics.py
# ../RMG-models/CombFlame2013/1609-Veloo/SMILES.txt
# ../RMG-models/CombFlame2013/1609-Veloo/mechanism.kinetics.py
# ../RMG-models/CombFlame2013/17-Malewicki/SMILES.txt
# ../RMG-models/CombFlame2013/17-Malewicki/mechanism.kinetics.py
# ../RMG-models/CombFlame2013/1907-Merchant/SMILES.txt
# ../RMG-models/CombFlame2013/1907-Merchant/mechanism.kinetics.py
# ../RMG-models/CombFlame2013/1939-Cai/SMILES.txt
# ../RMG-models/CombFlame2013/1939-Cai/mechanism.kinetics.py
# ../RMG-models/CombFlame2013/1958-Zhao/SMILES.txt
# ../RMG-models/CombFlame2013/1958-Zhao/mechanism.kinetics.py
# ../RMG-models/CombFlame2013/2291-Somers/SMILES.txt
# ../RMG-models/CombFlame2013/2291-Somers/mechanism.kinetics.py
# ../RMG-models/CombFlame2013/2319-Serinyel/SMILES.txt
# ../RMG-models/CombFlame2013/2319-Serinyel/mechanism.kinetics.py
# ../RMG-models/CombFlame2013/2343-Hansen/SMILES.txt
# ../RMG-models/CombFlame2013/2343-Hansen/mechanism.kinetics.py
# ../RMG-models/CombFlame2013/2680-Vranckx/SMILES.txt
# ../RMG-models/CombFlame2013/2680-Vranckx/mechanism.kinetics.py
# ../RMG-models/CombFlame2013/2693-Karwat/SMILES.txt
# ../RMG-models/CombFlame2013/2693-Karwat/mechanism.kinetics.py
# ../RMG-models/CombFlame2013/2712-Sarathy/SMILES.txt
# ../RMG-models/CombFlame2013/2712-Sarathy/mechanism.kinetics.py
# ../RMG-models/CombFlame2013/487-Schenk/SMILES.txt
# ../RMG-models/CombFlame2013/487-Schenk/mechanism.kinetics.py
# ../RMG-models/CombFlame2013/853-Alzueta/SMILES.txt
# ../RMG-models/CombFlame2013/853-Alzueta/mechanism.kinetics.py
# ../RMG-models/CombFlame2014/1135-Dames/SMILES.txt
# ../RMG-models/CombFlame2014/1135-Dames/mechanism.kinetics.py
# ../RMG-models/CombFlame2014/405-Cai/SMILES.txt
# ../RMG-models/CombFlame2014/405-Cai/unoptimizedmechanism.kinetics.py
# ../RMG-models/CombFlame2014/65-Darcy/SMILES.txt
# ../RMG-models/CombFlame2014/65-Darcy/mechanism.kinetics.py
# ../RMG-models/CombFlame2014/657-Jin/SMILES.txt
# ../RMG-models/CombFlame2014/657-Jin/mechanism.kinetics.py
# ../RMG-models/CombFlame2014/711-Allen/SMILES.txt
# ../RMG-models/CombFlame2014/711-Allen/mechanism.kinetics.py
# ../RMG-models/CombFlame2014/748-Liu/SMILES.txt
# ../RMG-models/CombFlame2014/748-Liu/mechanism.kinetics.py
# ../RMG-models/CombFlame2014/798-Cai/SMILES.txt
# ../RMG-models/CombFlame2014/798-Cai/mechanism.kinetics.py
# ../RMG-models/CombFlame2014/818-Zhang/SMILES.txt
# ../RMG-models/CombFlame2014/818-Zhang/mechanism.kinetics.py
# ../RMG-models/CombFlame2014/84-Wang/SMILES.txt
# ../RMG-models/CombFlame2014/84-Wang/mechanism.kinetics.py
# ../RMG-models/CombFlame2014/885-Xiong/SMILES.txt
# ../RMG-models/CombFlame2014/885-Xiong/mechanism.kinetics.py
# ../RMG-models/CombFlame2014/898-Wagnon/SMILES.txt
# ../RMG-models/CombFlame2014/898-Wagnon/mechanism.kinetics.py
# ../RMG-models/CombFlame2015/3755-Konnov/SMILES.txt
# ../RMG-models/CombFlame2015/3755-Konnov/mechanism.kinetics.py
# ../RMG-models/Gasoline_2/SMILES.txt
# ../RMG-models/Gasoline_2/llnl.gasoline.mar2014.chem.kinetics.py
# ../RMG-models/Gasoline_Surrogate/SMILES.txt
# ../RMG-models/Gasoline_Surrogate/Gasolinemechanism.kinetics.py
# ../RMG-models/GRI-17-species-mech/SMILES.txt
# ../RMG-models/GRI-17-species-mech/mechanism.kinetics.py
# ../RMG-models/GRI-mech-3.0/SMILES.txt
# ../RMG-models/GRI-mech-3.0/mechanism.kinetics.py
# ../RMG-models/H2/SMILES.txt
# ../RMG-models/H2/chem.kinetics.py
# ../RMG-models/H2-3/SMILES.txt
# ../RMG-models/H2-3/Burke_Konnov_Mech3.kinetics.py
# ../RMG-models/IJCK2013/638-Metcalfe/SMILES.txt
# ../RMG-models/IJCK2013/638-Metcalfe/mechanism.kinetics.py
# ../RMG-models/JPCA2013/1371-Sirjean/SMILES.txt
# ../RMG-models/JPCA2013/1371-Sirjean/mechanism.kinetics.py
# ../RMG-models/MatheuCH4/SMILES.txt
# ../RMG-models/MatheuCH4/Matheu_CH4_pyrolysis_gas_kinetics.kinetics.py
# ../RMG-models/MB-Dooley/SMILES.txt
# ../RMG-models/MB-Dooley/mb_cnf_08.kinetics.py
# ../RMG-models/MB-Farooq/SMILES.txt
# ../RMG-models/MB-Farooq/mmc1.kinetics.py
# ../RMG-models/MB-Fisher/SMILES.txt
# ../RMG-models/MB-Fisher/mbmechrev.kinetics.py
# ../RMG-models/n-Heptane/SMILES.txt
# ../RMG-models/n-Heptane/nc7_ver3.1_mech.kinetics.py
# ../RMG-models/Narayanaswamy/SMILES.txt
# ../RMG-models/Narayanaswamy/Narayanaswamy_2010_chemkin.kinetics.py
# ../RMG-models/PCI2013/225-Somers/SMILES.txt
# ../RMG-models/PCI2013/225-Somers/mechanism.kinetics.py
# ../RMG-models/PCI2013/259-Labbe/SMILES.txt
# ../RMG-models/PCI2013/259-Labbe/mechanism.kinetics.py
# ../RMG-models/PCI2013/269-Matsugi/SMILES.txt
# ../RMG-models/PCI2013/269-Matsugi/mechanism.kinetics.py
# ../RMG-models/PCI2013/289-Dagaut/SMILES.txt
# ../RMG-models/PCI2013/289-Dagaut/mechanism.kinetics.py
# ../RMG-models/PCI2013/297-Herbinet/SMILES.txt
# ../RMG-models/PCI2013/297-Herbinet/mechanism.kinetics.py
# ../RMG-models/PCI2013/325-Husson/SMILES.txt
# ../RMG-models/PCI2013/325-Husson/mechanism.kinetics.py
# ../RMG-models/PCI2013/335-Wang/SMILES.txt
# ../RMG-models/PCI2013/335-Wang/mechanism.kinetics.py
# ../RMG-models/PCI2013/353-Malewicki/SMILES.txt
# ../RMG-models/PCI2013/353-Malewicki/mechanism.kinetics.py
# ../RMG-models/PCI2013/361-Malewicki/SMILES.txt
# ../RMG-models/PCI2013/361-Malewicki/mechanism.kinetics.py
# ../RMG-models/PCI2013/401-Liu/SMILES.txt
# ../RMG-models/PCI2013/401-Liu/mechanism.kinetics.py
# ../RMG-models/PCI2013/411-Darcy/SMILES.txt
# ../RMG-models/PCI2013/411-Darcy/mechanism.kinetics.py
# ../RMG-models/PCI2013/527-Sheen/SMILES.txt
# ../RMG-models/PCI2013/527-Sheen/mechanism.kinetics.py
# ../RMG-models/PCI2013/599-Veloo/SMILES.txt
# ../RMG-models/PCI2013/599-Veloo/mechanism.kinetics.py
# ../RMG-models/PCI2013/617-Zhang/SMILES.txt
# ../RMG-models/PCI2013/617-Zhang/mechanism.kinetics.py
# ../RMG-models/PCI2015/0153-Marshall/SMILES.txt
# ../RMG-models/PCI2015/0153-Marshall/mechanism.kinetics.py
# ../RMG-models/PCI2015/0325-Nawdiyal/SMILES.txt
# ../RMG-models/PCI2015/0325-Nawdiyal/mechanism.kinetics.py
# ../RMG-models/PCI2015/0409-Zhang/SMILES.txt
# ../RMG-models/PCI2015/0409-Zhang/mechanism.kinetics.py
# ../RMG-models/Reduced-DRG-GRI-mech/SMILES.txt
# ../RMG-models/Reduced-DRG-GRI-mech/mechanism.kinetics.py
# ../RMG-models/Shamel-Propane/SMILES.txt
# ../RMG-models/Shamel-Propane/propane_full_mechanism.kinetics.py
# ../RMG-models/USC_Mech_ii/SMILES.txt
# ../RMG-models/USC_Mech_ii/USC_Mech_ver_II.kinetics.py
