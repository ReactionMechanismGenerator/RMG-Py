# %%
from IPython.display import Image, display

from rmgpy.molecule.molecule import Molecule
from rmgpy.molecule.resonance import (
    _clar_optimization,
    generate_clar_structures,
    generate_kekule_structure,
    generate_optimal_aromatic_resonance_structures,
    generate_resonance_structures,
)

# %%
def show(mol: Molecule):
    display(Image(mol._repr_png_()))

# %%
phenanthrene = Molecule(smiles="C1=CC=C2C(C=CC3=CC=CC=C32)=C1")
show(phenanthrene)

# %%
methylbenzophenanthrene = Molecule(smiles="C12=CC=CC=C1C3=C(C=C2)C(=CC4=C3C=CC=C4)C")
show(methylbenzophenanthrene)

# %%
mol_list: list[Molecule] = generate_clar_structures(phenanthrene)
for mol in mol_list:
    show(mol)

# %%
struct = Molecule().from_adjacency_list(
                """1  C u0 p0 c0 {2,S} {3,B} {5,B}
    2  C u0 p0 c0 {1,S} {4,B} {9,B}
    3  C u0 p0 c0 {1,B} {6,S} {10,B}
    4  C u0 p0 c0 {2,B} {7,S} {8,B}
    5  C u0 p0 c0 {1,B} {12,B} {17,S}
    6  C u0 p0 c0 {3,S} {7,D} {18,S}
    7  C u0 p0 c0 {4,S} {6,D} {19,S}
    8  C u0 p0 c0 {4,B} {13,B} {20,S}
    9  C u0 p0 c0 {2,B} {14,B} {23,S}
    10 C u0 p0 c0 {3,B} {11,B} {24,S}
    11 C u0 p0 c0 {10,B} {12,B} {15,S}
    12 C u0 p0 c0 {5,B} {11,B} {16,S}
    13 C u0 p0 c0 {8,B} {14,B} {21,S}
    14 C u0 p0 c0 {9,B} {13,B} {22,S}
    15 H u0 p0 c0 {11,S}
    16 H u0 p0 c0 {12,S}
    17 H u0 p0 c0 {5,S}
    18 H u0 p0 c0 {6,S}
    19 H u0 p0 c0 {7,S}
    20 H u0 p0 c0 {8,S}
    21 H u0 p0 c0 {13,S}
    22 H u0 p0 c0 {14,S}
    23 H u0 p0 c0 {9,S}
    24 H u0 p0 c0 {10,S}
    """
            )
show(struct)

# %%
for atom1 in mol_list[0].atoms:
    for atom2, bond in atom1.bonds.items():
        print(atom1, atom2, bond.order)
# Out:
# C C 1.5
# C C 1.5
# C C 1.0
# C C 1.0
# C C 1.5
# C C 1.5
# C C 1.5
# C C 1.0
# C C 1.5
# C C 1.0
# C C 1.5
# C C 1.5
# C C 1.5
# C C 1.5
# C H 1.0
# C C 1.0
# C C 2.0
# C H 1.0
# C C 2.0
# C C 1.0
# C H 1.0
# C C 1.5
# C C 1.5
# C H 1.0
# C C 1.5
# C C 1.5
# C H 1.0
# C C 1.5
# C C 1.5
# C H 1.0
# C C 1.5
# C C 1.5
# C H 1.0
# C C 1.5
# C C 1.5
# C H 1.0
# C C 1.5
# C C 1.5
# C H 1.0
# C C 1.5
# C C 1.5
# C H 1.0
# H C 1.0
# H C 1.0
# H C 1.0
# H C 1.0
# H C 1.0
# H C 1.0
# H C 1.0
# H C 1.0
# H C 1.0
# H C 1.0

# %%
# main rmg finds these
for mol in [Molecule(smiles="CC1=Cc2ccccc2C2=C1C=Cc1ccccc12"), Molecule(smiles="Cc1cc2c(c3c1C=Cc1ccccc1-3)C=CC=C2"), Molecule(smiles="CC1=Cc2ccccc2-c2c1ccc1c2C=CC=C1")]:
    show(mol)

# %%
mitene = Molecule().from_smiles("C1C2=C(CC3=C1C=CC1=CC4=CC5=CC6=CC7=C(CC8=C(C7)C=C7C=CC=C9CC%10=C(C=C%11C=CC=C%12C=C%13C=C%14C=C%15C=CC%16=C(C=C%17C=C%18C=CC=CC%18=CC%17=C%16)C%15C%15=CC=CC(C%13C%10=C%11%12)=C%14%15)C8=C79)C7=C6C(C6=CC8=C(CC6=C7)C=CC=C8)=C5C=C4C=C31)C1C3=C(CC4=CC5=C(C=CC=C5)C(C2)=C14)C=CC=C3")
mitene
# identifies 85 structures with the original stated method, 97 with the new one which has a smaller hull
# Out:
# Molecule(smiles="C1=CC2=CC3=CC4=C(C=C3C=C2C=C1)C1C(=CC2=CC3=CC5=CC=CC6=CC7=C(CC8=CC=CC9=CC%10=C(CC%11=C(C=C%12C=C%13C=C%14C=C%15C=CC%16=C(CC%17=C(C%16)CC%16=C%18C(=CC%19=C%16C=CC=C%19)CC%16=C(C=CC=C%16)C%17%18)C%15=CC%14=CC%13=C%13C%14=CC%15=C(C=CC=C%15)CC%14=CC%11=C%12%13)C%10)C7=C98)C(=C56)C3C3=C2C1=CC=C3)C=C4")

# %%
res = generate_clar_structures(mitene)

# %%
len(res)
# Out:
# 97

# %%
for mol in res:
    show(mol)
